# %% [markdown]
# # 03. Breadth First Search

# %% [markdown]
# ## 3.1. Explanation with Example
#
# Let us see how this algorithm works with an example. Here, we will use an undirected graph with 5 vertices.

# %% [markdown]
# ![Fig_1.png](attachment:Fig_1.png)

# %% [markdown]
# We begin from the vertex P, the BFS algorithmic program starts by putting it within the Visited list and puts all its adjacent vertices within the stack.

# %% [markdown]
# ![Fig_2.png](attachment:Fig_2.png)

# %% [markdown]
# Next, we have a tendency to visit the part at the front of the queue i.e. Q and visit its adjacent nodes. Since P has already been visited, we have a tendency to visit R instead.

# %% [markdown]
# ![Fig_3.png](attachment:Fig_3.png)

# %% [markdown]
# Vertex R has an unvisited adjacent vertex in T, thus we have a tendency to add that to the rear of the queue and visit S, which is at the front of the queue.

# %% [markdown]
# ![Fig_4.png](attachment:Fig_4.png)

# %% [markdown]
# ![Fig_5.png](attachment:Fig_5.png)

# %% [markdown]
# Now, only T remains within the queue since the only adjacent node of S i.e. P is already visited. We have a tendency to visit it.

# %% [markdown]
# ![Fig_6.png](attachment:Fig_6.png)

# %% [markdown]
# Since the queue is empty, we've completed the Traversal of the graph.

# %% [markdown]
# ## 3.2. Implementation using Python

# %% [markdown]
# ## Example 1.

# %%
graph = {
  'P' : ['Q','R','S'],
  'Q' : ['R'],
  'R' : ['T'],
  'S' : [],
  'T' : []
  
}

# %%
visited = [] # List for visited nodes.
queue = []     #Initialize a queue

# %%
def bfs(visited, graph, node): #function for BFS
  visited.append(node)
  queue.append(node)

  while queue:          # Creating loop to visit each node
    m = queue.pop(0) 
    print (m, end = " ") 

    for neighbour in graph[m]:
      if neighbour not in visited:
        visited.append(neighbour)
        queue.append(neighbour)

# %%
# Driver Code
print("Following is the Breadth-First Search")
bfs(visited, graph, 'P')    # function calling
# Out:
# Following is the Breadth-First Search
# P Q R S T

# %% [markdown]
# ## Example 2.

# %%
graph = {
  '0' : ['1','2','3'],
  '1' : ['2'],
  '2' : ['0','4'],
  '3' : [],
  '4' : []
 
}

# %%
visited = [] # List for visited nodes.
queue = []     #Initialize a queue

# %%
def bfs(visited, graph, node): #function for BFS
  visited.append(node)
  queue.append(node)

  while queue:          # Creating loop to visit each node
    m = queue.pop(0) 
    print (m, end = " ") 

    for neighbour in graph[m]:
      if neighbour not in visited:
        visited.append(neighbour)
        queue.append(neighbour)

# %%
# Driver Code
print("Following is the Breadth-First Search")
bfs(visited, graph, '0')    # function calling
# Out:
# Following is the Breadth-First Search
# 0 1 2 3 4

# %% [markdown]
# ## Example 3.

# %% [markdown]
# ![Screenshot%202021-11-24%20at%207.20.51%20PM.png](attachment:Screenshot%202021-11-24%20at%207.20.51%20PM.png)

# %%
graph = {
  'A' : ['B','C'],
  'B' : ['D','E'],
  'C' : ['F'],
  'D' : [],
  'E' : ['F'],
  'F' : []
 
}

# %%
visited = [] # List for visited nodes.
queue = []     #Initialize a queue

# %%
def bfs(visited, graph, node): #function for BFS
  visited.append(node)
  queue.append(node)

  while queue:          # Creating loop to visit each node
    m = queue.pop(0) 
    print (m, end = " ") 

    for neighbour in graph[m]:
      if neighbour not in visited:
        visited.append(neighbour)
        queue.append(neighbour)

# %%
# Driver Code
print("Following is the Breadth-First Search")
bfs(visited, graph, 'B')    # function calling
# Out:
# Following is the Breadth-First Search
# B D E F
